# %%
# Import 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Size Array
data_size = [5, 5, 5]

# Data type : We use boolean
data = np.ones(data_size, dtype=bool)  # Mengganti dtype=np.bool menjadi dtype=bool

# Control Transparency
alpha = 0.9

# Control Alpha Values and Control colors of 3D Cube
colors = np.empty(data_size + [4], dtype=np.float32)
colors[:] = [1, 1, 0, alpha]  # red

# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Set axis labels
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Set plot title
ax.set_title('3D Voxel Plot')

# Voxels is to use to cutomize size
ax.voxels(data, facecolors=colors)

# Display the plot
plt.show()
